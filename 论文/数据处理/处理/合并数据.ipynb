# %%
import pandas as pd

# %%
author =  pd.read_csv(r'E:\vspy\论文相关git\论文数据集\论文初步方案\数据处理\b+信息.csv')
comments = pd.read_csv(r'E:\vspy\论文相关git\论文数据集\论文初步方案\数据处理\筛选后.csv')

# %%
data = comments.merge(author,how = 'left',on ='author')

# %%
data.head()
# Out:
#             author                                               body  \
# 0  MetricExpansion  Those stats come from the test. [Echoing the c...
# 1  MetricExpansion  That's great to hear! I hope you know that, de...
# 2  MetricExpansion  I can totally agree on reticence! With respect...
# 3  MetricExpansion  I took it several times. I'm typed as TYPE_MEN...
# 4  MetricExpansion  Gawd it's like we don't even need drugs to be ...
#
#    word_count   age country  agreeableness  openness  conscientiousness  \
# 0       149.0  23.0     NaN           30.0      70.0               15.0
# 1       316.0  23.0     NaN           30.0      70.0               15.0
# 2       143.0  23.0     NaN           30.0      70.0               15.0
# 3        41.0  23.0     NaN           30.0      70.0               15.0
# 4        11.0  23.0     NaN           30.0      70.0               15.0
#
#    extraversion  neuroticism  num_comments  en_comments  \
# ...

# %%
data.drop(['agreeableness','openness','conscientiousness','extraversion','neuroticism'],axis=1)
# Out:
#                        author  \
# 0             MetricExpansion
# 1             MetricExpansion
# 2             MetricExpansion
# 3             MetricExpansion
# 4             MetricExpansion
# ...                       ...
# 1874996  Q1189998819991197253
# 1874997       UltraGopnik3000
# 1874998             rotanocaB
# 1874999           pikachuuuuu
# 1875000              FusRoDan
#
#                                                       body  word_count   age  \
# 0        Those stats come from the test. [Echoing the c...       149.0  23.0
# 1        That's great to hear! I hope you know that, de...       316.0  23.0
# 2        I can totally agree on reticence! With respect...       143.0  23.0
# 3        I took it several times. I'm typed as TYPE_MEN...        41.0  23.0
# 4        Gawd it's like we don't even need drugs to be ...        11.0  23.0
# ...                                                    ...         ...   ...
# ...

# %%
data.to_csv('训练数据.csv',index = False)
